# %%
# !git clone https://github.com/shafieiali42/PromptAD-master.git
# Out:
# Cloning into 'PromptAD-master'...
# remote: Enumerating objects: 968, done.
# remote: Counting objects: 100% (116/116), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 968 (delta 52), reused 84 (delta 29), pack-reused 852 (from 1)
# Receiving objects: 100% (968/968), 54.04 MiB | 40.16 MiB/s, done.
# Resolving deltas: 100% (180/180), done.

# %%
# %cd PromptAD-master
# %pwd
# %mkdir mvtec_anomaly_detection
# %cd mvtec_anomaly_detection
# Out:
# /kaggle/working/PromptAD-master
# /kaggle/working/PromptAD-master/mvtec_anomaly_detection

# %%
# !kaggle datasets download -d ipythonx/mvtec-ad
! unzip -q mvtec-ad.zip
# !rm mvtec-ad.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ipythonx/mvtec-ad
# License(s): copyright-authors
# ...
# 100%|██████████████████████████████████████▉| 4.91G/4.91G [00:27<00:00, 104MB/s]
# 100%|███████████████████████████████████████| 4.91G/4.91G [00:27<00:00, 189MB/s]

# %%
# %cd ..
# %pwd
# Out:
# /kaggle/working/PromptAD-master
# '/kaggle/working/PromptAD-master'

# %%
# %mkdir ViSA_anomaly_detection
# %cd ViSA_anomaly_detection
# !wget https://amazon-visual-anomaly.s3.us-west-2.amazonaws.com/VisA_20220922.tar
# !tar -xvf VisA_20220922.tar
# !rm VisA_20220922.tar
# Out:
# mkdir: cannot create directory 'ViSA_anomaly_detection': File exists
# /kaggle/working/PromptAD-master/ViSA_anomaly_detection
# --2024-09-24 16:45:20--  https://amazon-visual-anomaly.s3.us-west-2.amazonaws.com/VisA_20220922.tar
# Resolving amazon-visual-anomaly.s3.us-west-2.amazonaws.com (amazon-visual-anomaly.s3.us-west-2.amazonaws.com)... 52.218.183.18, 3.5.83.17, 3.5.78.199, ...
# Connecting to amazon-visual-anomaly.s3.us-west-2.amazonaws.com (amazon-visual-anomaly.s3.us-west-2.amazonaws.com)|52.218.183.18|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1929840640 (1.8G) [application/x-tar]
# Saving to: 'VisA_20220922.tar'
#
# VisA_20220922.tar   100%[===================>]   1.80G  24.3MB/s    in 62s
#
# 2024-09-24 16:46:23 (29.6 MB/s) - 'VisA_20220922.tar' saved [1929840640/1929840640]
#
# candle/
# candle/image_anno.csv
# candle/Data/
# candle/Data/Images/
# candle/Data/Images/Anomaly/
# candle/Data/Images/Anomaly/001.JPG
# ...

# %%
# %cd ..
# %pwd
# Out:
# /kaggle/working/PromptAD-master
# '/kaggle/working/PromptAD-master'

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.4/952.4 kB 6.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.8/427.8 kB 25.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 60.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 61.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 80.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.0/43.0 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 70.0.0
#     Uninstalling setuptools-70.0.0:
#       Successfully uninstalled setuptools-70.0.0
# ...

# %%
# !python datasets/prepare_visa_public.py

# %%
# !python run_cls.py
# Out:
# python train_cls.py --dataset mvtec --k-shot 1 --class_name carpet
# python train_cls.py --dataset mvtec --k-shot 1 --class_name leather
# python train_cls.py --dataset mvtec --k-shot 1 --class_name wood
# python train_cls.py --dataset mvtec --k-shot 1 --class_name bottle
# python train_cls.py --dataset mvtec --k-shot 1 --class_name capsule
# python train_cls.py --dataset mvtec --k-shot 1 --class_name hazelnut
# python train_cls.py --dataset visa --k-shot 1 --class_name candle
# python train_cls.py --dataset visa --k-shot 1 --class_name capsules
# python train_cls.py --dataset visa --k-shot 1 --class_name cashew
# python train_cls.py --dataset visa --k-shot 1 --class_name chewinggum
# python train_cls.py --dataset visa --k-shot 1 --class_name fryum
# python train_cls.py --dataset visa --k-shot 1 --class_name macaroni1
# python train_cls.py --dataset visa --k-shot 1 --class_name macaroni2
# python train_cls.py --dataset visa --k-shot 1 --class_name pcb1
# ...

# %%
# !zip -r mvtec_visa_k1_files_cls.zip /kaggle/working/PromptAD-master/result/mvtec/k_1
# Out:
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_1/ (stored 0%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_1/imgs/ (stored 0%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_1/imgs/carpet-good-019_ori.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_1/imgs/carpet-metal_contamination-012_PromptAD.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_1/imgs/carpet-thread-006_PromptAD.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_1/imgs/carpet-metal_contamination-008_PromptAD.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_1/imgs/carpet-color-007_gt.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_1/imgs/carpet-hole-003_gt.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_1/imgs/carpet-metal_contamination-007_ori.jpg (deflated 1%)
# ...

# %%
# !zip -r mvtec_visa_k2_files_cls.zip /kaggle/working/PromptAD-master/result/mvtec/k_2
# Out:
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_2/ (stored 0%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_2/imgs/ (stored 0%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_2/imgs/carpet-good-019_ori.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_2/imgs/carpet-metal_contamination-012_PromptAD.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_2/imgs/carpet-thread-006_PromptAD.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_2/imgs/carpet-metal_contamination-008_PromptAD.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_2/imgs/carpet-color-007_gt.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_2/imgs/carpet-hole-003_gt.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_2/imgs/carpet-metal_contamination-007_ori.jpg (deflated 1%)
# ...

# %%
# !zip -r mvtec_visa_k4_files_cls.zip /kaggle/working/PromptAD-master/result/mvtec/k_4
# Out:
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/ (stored 0%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/imgs/ (stored 0%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/imgs/carpet-good-019_ori.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/imgs/carpet-metal_contamination-012_PromptAD.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/imgs/carpet-thread-006_PromptAD.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/imgs/carpet-metal_contamination-008_PromptAD.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/imgs/carpet-color-007_gt.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/imgs/carpet-hole-003_gt.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/imgs/carpet-metal_contamination-007_ori.jpg (deflated 1%)
# ...

# %%
# !zip -r visa_k1_files_cls.zip /kaggle/working/PromptAD-master/result/visa/k_1
# Out:
# updating: kaggle/working/PromptAD-master/result/visa/k_1/ (stored 0%)
# updating: kaggle/working/PromptAD-master/result/visa/k_1/imgs/ (stored 0%)
# updating: kaggle/working/PromptAD-master/result/visa/k_1/checkpoint/ (stored 0%)
# updating: kaggle/working/PromptAD-master/result/visa/k_1/checkpoint/CLS-Seed_111-pipe_fryum-k_1-check_point.pt (deflated 8%)
# updating: kaggle/working/PromptAD-master/result/visa/k_1/checkpoint/CLS-Seed_111-macaroni2-k_1-check_point.pt (deflated 8%)
# updating: kaggle/working/PromptAD-master/result/visa/k_1/checkpoint/CLS-Seed_111-capsules-k_1-check_point.pt (deflated 8%)
# updating: kaggle/working/PromptAD-master/result/visa/k_1/checkpoint/CLS-Seed_111-cashew-k_1-check_point.pt (deflated 8%)
# updating: kaggle/working/PromptAD-master/result/visa/k_1/checkpoint/CLS-Seed_111-macaroni1-k_1-check_point.pt (deflated 8%)
# updating: kaggle/working/PromptAD-master/result/visa/k_1/checkpoint/CLS-Seed_111-pcb1-k_1-check_point.pt (deflated 8%)
# ...

# %%
# !zip -r visa_k2_files_cls.zip /kaggle/working/PromptAD-master/result/visa/k_2
# Out:
# updating: kaggle/working/PromptAD-master/result/visa/k_2/ (stored 0%)
# updating: kaggle/working/PromptAD-master/result/visa/k_2/imgs/ (stored 0%)
# updating: kaggle/working/PromptAD-master/result/visa/k_2/checkpoint/ (stored 0%)
# updating: kaggle/working/PromptAD-master/result/visa/k_2/checkpoint/CLS-Seed_111-pcb1-k_2-check_point.pt (deflated 8%)
# updating: kaggle/working/PromptAD-master/result/visa/k_2/checkpoint/CLS-Seed_111-macaroni2-k_2-check_point.pt (deflated 8%)
# updating: kaggle/working/PromptAD-master/result/visa/k_2/checkpoint/CLS-Seed_111-fryum-k_2-check_point.pt (deflated 8%)
# updating: kaggle/working/PromptAD-master/result/visa/k_2/checkpoint/CLS-Seed_111-cashew-k_2-check_point.pt (deflated 8%)
# updating: kaggle/working/PromptAD-master/result/visa/k_2/checkpoint/CLS-Seed_111-pcb3-k_2-check_point.pt (deflated 8%)
# updating: kaggle/working/PromptAD-master/result/visa/k_2/checkpoint/CLS-Seed_111-pcb2-k_2-check_point.pt (deflated 8%)
# ...

# %%
# !zip -r visa_k4_files_cls.zip /kaggle/working/PromptAD-master/result/visa/k_4
# Out:
# updating: kaggle/working/PromptAD-master/result/visa/k_4/ (stored 0%)
# updating: kaggle/working/PromptAD-master/result/visa/k_4/imgs/ (stored 0%)
# updating: kaggle/working/PromptAD-master/result/visa/k_4/checkpoint/ (stored 0%)
# updating: kaggle/working/PromptAD-master/result/visa/k_4/checkpoint/CLS-Seed_111-macaroni1-k_4-check_point.pt (deflated 8%)
# updating: kaggle/working/PromptAD-master/result/visa/k_4/checkpoint/CLS-Seed_111-capsules-k_4-check_point.pt (deflated 8%)
# updating: kaggle/working/PromptAD-master/result/visa/k_4/checkpoint/CLS-Seed_111-macaroni2-k_4-check_point.pt (deflated 8%)
# updating: kaggle/working/PromptAD-master/result/visa/k_4/checkpoint/CLS-Seed_111-chewinggum-k_4-check_point.pt (deflated 8%)
# updating: kaggle/working/PromptAD-master/result/visa/k_4/checkpoint/CLS-Seed_111-fryum-k_4-check_point.pt (deflated 8%)
# updating: kaggle/working/PromptAD-master/result/visa/k_4/checkpoint/CLS-Seed_111-cashew-k_4-check_point.pt (deflated 8%)
# ...

# %%
print("Done")
# Out:
# Done
