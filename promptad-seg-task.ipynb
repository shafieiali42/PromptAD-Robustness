# %%
# !git clone https://github.com/shafieiali42/PromptAD-master.git
# Out:
# Cloning into 'PromptAD-master'...
# remote: Enumerating objects: 263, done.
# remote: Counting objects: 100% (263/263), done.
# remote: Compressing objects: 100% (167/167), done.
# remote: Total 263 (delta 111), reused 228 (delta 80), pack-reused 0 (from 0)
# Receiving objects: 100% (263/263), 7.76 MiB | 20.37 MiB/s, done.
# Resolving deltas: 100% (111/111), done.

# %%
# %cd PromptAD-master
# %pwd
# %mkdir mvtec_anomaly_detection
# %cd mvtec_anomaly_detection
# Out:
# /kaggle/working/PromptAD-master
# /kaggle/working/PromptAD-master/mvtec_anomaly_detection

# %%
# !kaggle datasets download -d ipythonx/mvtec-ad
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ipythonx/mvtec-ad
# License(s): copyright-authors
# ...
# 100%|██████████████████████████████████████▉| 4.89G/4.91G [00:33<00:00, 193MB/s]
# 100%|███████████████████████████████████████| 4.91G/4.91G [00:33<00:00, 159MB/s]

# %%
! unzip -q mvtec-ad.zip
# Out:
# replace bottle/ground_truth/broken_large/000_mask.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
# !rm mvtec-ad.zip

# %%
# %cd ..
# %pwd
# Out:
# /kaggle/working/PromptAD-master
# '/kaggle/working/PromptAD-master'

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.4/952.4 kB 6.7 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.8/427.8 kB 28.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 63.6 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 61.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 75.6 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.0/43.0 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 70.0.0
#     Uninstalling setuptools-70.0.0:
#       Successfully uninstalled setuptools-70.0.0
# ...

# %%
# !python train_seg.py --dataset mvtec --k-shot 1 --class_name carpet
# Out:
# 100%|████████████████████████████████████████| 834M/834M [00:02<00:00, 286MiB/s]
# ...

# %%
# !zip -r mvtec_k1_files.zip /kaggle/working/PromptAD-master/result/mvtec/k_1
# Out:
# updating: kaggle/working/PromptAD-master/result/mvtec/k_1/ (stored 0%)
# updating: kaggle/working/PromptAD-master/result/mvtec/k_1/imgs/ (stored 0%)
# updating: kaggle/working/PromptAD-master/result/mvtec/k_1/imgs/carpet-color-010_gt.jpg (deflated 1%)
# updating: kaggle/working/PromptAD-master/result/mvtec/k_1/imgs/carpet-color-015_PromptAD.jpg (deflated 1%)
# updating: kaggle/working/PromptAD-master/result/mvtec/k_1/imgs/carpet-thread-018_gt.jpg (deflated 1%)
# updating: kaggle/working/PromptAD-master/result/mvtec/k_1/imgs/carpet-good-024_PromptAD.jpg (deflated 1%)
# updating: kaggle/working/PromptAD-master/result/mvtec/k_1/imgs/carpet-metal_contamination-004_gt.jpg (deflated 1%)
# updating: kaggle/working/PromptAD-master/result/mvtec/k_1/imgs/carpet-thread-000_PromptAD.jpg (deflated 1%)
# updating: kaggle/working/PromptAD-master/result/mvtec/k_1/imgs/carpet-color-010_PromptAD.jpg (deflated 1%)
# ...

# %%
print("Hi")
# Out:
# Hi

# %%
# !python train_seg.py --dataset mvtec --k-shot 2 --class_name carpet
# Out:
# /kaggle/working/PromptAD-master/PromptAD/CLIPAD/factory.py:87: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# !zip -r mvtec_k2_files.zip /kaggle/working/PromptAD-master/result/mvtec/k_2
# Out:
# updating: kaggle/working/PromptAD-master/result/mvtec/k_2/ (stored 0%)
# updating: kaggle/working/PromptAD-master/result/mvtec/k_2/imgs/ (stored 0%)
# updating: kaggle/working/PromptAD-master/result/mvtec/k_2/imgs/carpet-color-010_gt.jpg (deflated 1%)
# updating: kaggle/working/PromptAD-master/result/mvtec/k_2/imgs/carpet-color-015_PromptAD.jpg (deflated 1%)
# updating: kaggle/working/PromptAD-master/result/mvtec/k_2/imgs/carpet-thread-018_gt.jpg (deflated 1%)
# updating: kaggle/working/PromptAD-master/result/mvtec/k_2/imgs/carpet-good-024_PromptAD.jpg (deflated 1%)
# updating: kaggle/working/PromptAD-master/result/mvtec/k_2/imgs/carpet-metal_contamination-004_gt.jpg (deflated 1%)
# updating: kaggle/working/PromptAD-master/result/mvtec/k_2/imgs/carpet-thread-000_PromptAD.jpg (deflated 1%)
# updating: kaggle/working/PromptAD-master/result/mvtec/k_2/imgs/carpet-color-010_PromptAD.jpg (deflated 1%)
# ...

# %%
print("Done")
# Out:
# Done

# %%
# !python train_seg.py --dataset mvtec --k-shot 4 --class_name carpet
# Out:
# /kaggle/working/PromptAD-master/PromptAD/CLIPAD/factory.py:87: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# !zip -r mvtec_k4_files.zip /kaggle/working/PromptAD-master/result/mvtec/k_4
# Out:
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/ (stored 0%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/imgs/ (stored 0%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/imgs/carpet-color-010_gt.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/imgs/carpet-color-015_PromptAD.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/imgs/carpet-thread-018_gt.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/imgs/carpet-good-024_PromptAD.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/imgs/carpet-metal_contamination-004_gt.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/imgs/carpet-thread-000_PromptAD.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/imgs/carpet-color-010_PromptAD.jpg (deflated 1%)
# ...

# %%
print("Done")
# Out:
# Done

# %% [markdown]
# ## Testing

# %%
# !python test_seg.py --dataset mvtec --k-shot 1 --class_name carpet
# Out:
# /kaggle/working/PromptAD-master/PromptAD/CLIPAD/factory.py:87: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
print("Done")
# Out:
# Done

# %%
# !zip -r mvtec_k1_files_after_test.zip /kaggle/working/PromptAD-master/result/mvtec/k_1
# Out:
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_1/ (stored 0%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_1/imgs/ (stored 0%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_1/imgs/carpet-color-010_gt.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_1/imgs/carpet-color-015_PromptAD.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_1/imgs/carpet-thread-018_gt.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_1/imgs/carpet-good-024_PromptAD.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_1/imgs/carpet-metal_contamination-004_gt.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_1/imgs/carpet-thread-000_PromptAD.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_1/imgs/carpet-color-010_PromptAD.jpg (deflated 1%)
# ...

# %%
# !python test_seg.py --dataset mvtec --k-shot 2 --class_name carpet
# Out:
# /kaggle/working/PromptAD-master/PromptAD/CLIPAD/factory.py:87: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# !zip -r mvtec_k2_files_after_test.zip /kaggle/working/PromptAD-master/result/mvtec/k_2
# Out:
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_2/ (stored 0%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_2/imgs/ (stored 0%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_2/imgs/carpet-color-010_gt.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_2/imgs/carpet-color-015_PromptAD.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_2/imgs/carpet-thread-018_gt.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_2/imgs/carpet-good-024_PromptAD.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_2/imgs/carpet-metal_contamination-004_gt.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_2/imgs/carpet-thread-000_PromptAD.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_2/imgs/carpet-color-010_PromptAD.jpg (deflated 1%)
# ...

# %%
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet
# Out:
# /kaggle/working/PromptAD-master/PromptAD/CLIPAD/factory.py:87: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# !zip -r mvtec_k4_files_after_test.zip /kaggle/working/PromptAD-master/result/mvtec/k_4
# Out:
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/ (stored 0%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/imgs/ (stored 0%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/imgs/carpet-color-010_gt.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/imgs/carpet-color-015_PromptAD.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/imgs/carpet-thread-018_gt.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/imgs/carpet-good-024_PromptAD.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/imgs/carpet-metal_contamination-004_gt.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/imgs/carpet-thread-000_PromptAD.jpg (deflated 1%)
#   adding: kaggle/working/PromptAD-master/result/mvtec/k_4/imgs/carpet-color-010_PromptAD.jpg (deflated 1%)
# ...
