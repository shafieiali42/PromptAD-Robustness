# %%
# !git clone https://github.com/shafieiali42/PromptAD-master.git
# Out:
# Cloning into 'PromptAD-master'...
# remote: Enumerating objects: 870, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 870 (delta 6), reused 6 (delta 0), pack-reused 852 (from 1)
# Receiving objects: 100% (870/870), 48.90 MiB | 36.85 MiB/s, done.
# Resolving deltas: 100% (134/134), done.

# %%
# %cd PromptAD-master
# %pwd
# %mkdir mvtec_anomaly_detection
# %cd mvtec_anomaly_detection
# Out:
# /kaggle/working/PromptAD-master
# /kaggle/working/PromptAD-master/mvtec_anomaly_detection

# %%
# !kaggle datasets download -d ipythonx/mvtec-ad
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ipythonx/mvtec-ad
# License(s): copyright-authors
# ...
# 100%|██████████████████████████████████████▉| 4.90G/4.91G [00:21<00:00, 174MB/s]
# 100%|███████████████████████████████████████| 4.91G/4.91G [00:21<00:00, 240MB/s]

# %%
! unzip -q mvtec-ad.zip

# %%
# !rm mvtec-ad.zip

# %%
# %cd ..
# %pwd
# Out:
# /kaggle/working/PromptAD-master
# '/kaggle/working/PromptAD-master'

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.4/952.4 kB 6.7 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.8/427.8 kB 26.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 65.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 62.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 1.7 MB/s eta 0:00:000:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.0/43.0 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 70.0.0
#     Uninstalling setuptools-70.0.0:
#       Successfully uninstalled setuptools-70.0.0
# ...

# %% [markdown]
# **Gaussian noise**

# %%
# !python test_seg.py --dataset mvtec --k-shot 1 --class_name carpet --corrupt true --corruption gaussian_noise --severity 1
# Out:
# Corruption type: gaussian_noise
# severity: 1
# 100%|████████████████████████████████████████| 834M/834M [00:03<00:00, 239MiB/s]
# ...

# %%
# !python test_seg.py --dataset mvtec --k-shot 1 --class_name carpet --corrupt true --corruption gaussian_noise --severity 2
# Out:
# Corruption type: gaussian_noise
# severity: 2
# /kaggle/working/PromptAD-master/PromptAD/CLIPAD/factory.py:87: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# !python test_seg.py --dataset mvtec --k-shot 1 --class_name carpet --corrupt true --corruption gaussian_noise --severity 3
# Out:
# Corruption type: gaussian_noise
# severity: 3
# /kaggle/working/PromptAD-master/PromptAD/CLIPAD/factory.py:87: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# !python test_seg.py --dataset mvtec --k-shot 1 --class_name carpet --corrupt true --corruption gaussian_noise --severity 4
# Out:
# Corruption type: gaussian_noise
# severity: 4
# /kaggle/working/PromptAD-master/PromptAD/CLIPAD/factory.py:87: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# !python test_seg.py --dataset mvtec --k-shot 1 --class_name carpet --corrupt true --corruption gaussian_noise --severity 5
# Out:
# Corruption type: gaussian_noise
# severity: 5
# /kaggle/working/PromptAD-master/PromptAD/CLIPAD/factory.py:87: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# !python test_seg.py --dataset mvtec --k-shot 2 --class_name carpet --corrupt true --corruption gaussian_noise --severity 1
# !python test_seg.py --dataset mvtec --k-shot 2 --class_name carpet --corrupt true --corruption gaussian_noise --severity 2
# !python test_seg.py --dataset mvtec --k-shot 2 --class_name carpet --corrupt true --corruption gaussian_noise --severity 3
# !python test_seg.py --dataset mvtec --k-shot 2 --class_name carpet --corrupt true --corruption gaussian_noise --severity 4
# !python test_seg.py --dataset mvtec --k-shot 2 --class_name carpet --corrupt true --corruption gaussian_noise --severity 5
# Out:
# Corruption type: gaussian_noise
# severity: 1
# /kaggle/working/PromptAD-master/PromptAD/CLIPAD/factory.py:87: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet --corrupt true --corruption gaussian_noise --severity 1
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet --corrupt true --corruption gaussian_noise --severity 2
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet --corrupt true --corruption gaussian_noise --severity 3
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet --corrupt true --corruption gaussian_noise --severity 4
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet --corrupt true --corruption gaussian_noise --severity 5
# Out:
# Corruption type: gaussian_noise
# severity: 1
# /kaggle/working/PromptAD-master/PromptAD/CLIPAD/factory.py:87: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %% [markdown]
# **Shot noise**

# %%
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet --corrupt true --corruption shot_noise --severity 1
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet --corrupt true --corruption shot_noise --severity 2
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet --corrupt true --corruption shot_noise --severity 3
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet --corrupt true --corruption shot_noise --severity 4
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet --corrupt true --corruption shot_noise --severity 5
# Out:
# Corruption type: shot_noise
# severity: 1
# /kaggle/working/PromptAD-master/PromptAD/CLIPAD/factory.py:87: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet --corrupt true --corruption impulse_noise --severity 1
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet --corrupt true --corruption impulse_noise --severity 2
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet --corrupt true --corruption impulse_noise --severity 3
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet --corrupt true --corruption impulse_noise --severity 4
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet --corrupt true --corruption impulse_noise --severity 5
# Out:
# Corruption type: impulse_noise
# severity: 1
# /kaggle/working/PromptAD-master/PromptAD/CLIPAD/factory.py:87: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet --corrupt true --corruption motion_blur --severity 1
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet --corrupt true --corruption motion_blur --severity 2
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet --corrupt true --corruption motion_blur --severity 3
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet --corrupt true --corruption motion_blur --severity 4
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet --corrupt true --corruption motion_blur --severity 5
# Out:
# Corruption type: motion_blur
# severity: 1
# /kaggle/working/PromptAD-master/PromptAD/CLIPAD/factory.py:87: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet --corrupt true --corruption zoom_blur --severity 1
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet --corrupt true --corruption zoom_blur --severity 2
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet --corrupt true --corruption zoom_blur --severity 3
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet --corrupt true --corruption zoom_blur --severity 4
# !python test_seg.py --dataset mvtec --k-shot 4 --class_name carpet --corrupt true --corruption zoom_blur --severity 5
# Out:
# Corruption type: zoom_blur
# severity: 1
# /kaggle/working/PromptAD-master/PromptAD/CLIPAD/factory.py:87: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...
